# %% [markdown]
# ### voir dans les dossiers drives pour les notebooks pour ADI

# %% [markdown]
# ### Exercise:  Neural network
# **Source**: http://neuralnetworksanddeeplearning.com/chap1.html
# Try creating a network with just two layers - an input and an output layer,
# no hidden layer - with 784 and 10 neurons, respectively.
# Train the network using stochastic gradient descent. What classification accuracy can you achieve?

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, models
from tensorflow.keras.datasets import mnist

#set random seed
seed = 42
np.random.seed(seed)
tf.random.set_seed(seed)

# Load the MNIST dataset
(x_train, y_train), (x_test, y_test) = mnist.load_data()

# Preprocess the data
x_train, x_test = x_train / 255.0, x_test / 255.0

# Build the neural network model with an input layer and output layer with 10 neurons for classification

model = models.Sequential([
    layers.Flatten(input_shape=(28, 28)),  
    layers.Dense(10, activation='softmax') 
])

# Compile the model with stochastic gradient descent
model.compile(optimizer='sgd', 
              loss='sparse_categorical_crossentropy',
              metrics=['accuracy'])

# Train the model
model.fit(x_train, y_train, epochs=5)

# Evaluate the model on the test set
loss_test, acc_test = model.evaluate(x_test, y_test)
print(f"\nTest accuracy: {round(acc_test,3)}")
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.7790 - accuracy: 0.8182
# Epoch 2/5
# 1875/1875 [==============================] - 6s 3ms/step - loss: 0.4565 - accuracy: 0.8798
# Epoch 3/5
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4037 - accuracy: 0.8910
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.3770 - accuracy: 0.8965
# Epoch 5/5
# ...
# 313/313 [==============================] - 1s 2ms/step - loss: 0.3358 - accuracy: 0.9091
#
# Test accuracy: 0.909

# %% [markdown]
# ### learning Markov chain
# ### Resources:
# ### https://www.datacamp.com/tutorial/markov-chains-python-tutorial
# ### https://www.deeplearningbook.org/contents/monte_carlo.html ( 17.3 )
# ### https://setosa.io/ev/markov-chains/
# ### https://www.cs.princeton.edu/courses/archive/fall13/cos126/assignments/markov.html

# %%
#Implementation 
#https://www.cs.princeton.edu/courses/archive/fall13/cos126/assignments/markov.html
"""
Demander à chatgpt c'est quoi un modèle de chaine de markov?
Une chaîne de Markov est un modèle qui représente une séquence d'événements où la probabilité d'un événement 
futur dépend uniquement de l'état actuel, et non des états antérieurs. 
Cela signifie que l'évolution du système est "mémoire courte".
Un exemple simple est le modèle de météo. Supposons que le temps puisse être soit "ensoleillé" (S), 
    soit "nuageux" (C), soit "pluvieux" (R). La transition entre ces états peut être modélisée comme une chaîne de Markov.

Voici une matrice de transition possible pour ce modèle :
          | S    C    R
-----------------------
    S     | 0.7  0.2  0.1
    C     | 0.3  0.4  0.3
    R     | 0.2  0.3  0.5
PS: TRY TO UNDERSTAND MORE ABOUT :/
"""
# import random
# from collections import defaultdict

# def build_markov_model(text):
#     markov_model = defaultdict(list)

#     # Iterate through the text to build the Markov model
#     for i in range(len(text) - 1):
#         current_char = text[i]
#         next_char = text[i + 1]
#         markov_model[current_char].append(next_char)

#     return markov_model

# def generate_text(markov_model, length):
#     # Randomly select a starting character
#     current_char = random.choice(list(markov_model.keys()))
#     generated_text = [current_char]

#     # Generate text based on the Markov model
#     for _ in range(length - 1):
#         if current_char not in markov_model:
#             break  # Stop if the current character has no following characters
#         next_char = random.choice(markov_model[current_char])
#         generated_text.append(next_char)
#         current_char = next_char

#     return ''.join(generated_text)

# %%
# test
# input_text = "Microsoft said Tuesday the company would comply with a preliminary ruling by Federal District Court Judge Ronald H. Whyte that Microsoft is no longer able to use the Java Compatibility Logo on its packaging and websites for Internet Explorer and Software Developers Kit for Java."
# order_1_markov_model = build_markov_model(input_text)
# generated_text = generate_text(order_1_markov_model, length=7)
# generated_text
# Out:
# 'ulorudg'
